# %%
#we import all they key libraries needed in this notebook
import numpy as np
import pandas as pd
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import matplotlib as matplotlib

from visualize import plotColsOnMap
from format import removeEmptyRows, removeRed, objToNum, filterDepth, roundCoord

# %% [markdown]
# # Tang depth integrated visualizations
# This is meant to replicate the visualization done in the paper and see why the differences might occur.

# %%
keepers = ['LATITUDE', 'LONGITUDE', 'DEPTH (m)','Trichodesmium nifH Gene (x106 copies m-2)', 'Total UCYN-A nifH Gene (x106 copies m-2)','UCYN-B nifH Gene (x106 copies m-2)',"UCYN-A nifH Gene (x106 copies m-2)"]

# %%
tang_nifh = pd.read_csv("../csv/Tang_GeophysicalResLett_2019_Data_depth_int.csv")
print(tang_nifh.info())
tang_nifh.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 42 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   SOURCE: Data                                                    21 non-null     object
#  1   METHODS:                  Sampling/Analysis                     263 non-null    object
#  2   DATE (yyyy-mm-dd)                                               263 non-null    object
#  3   LATITUDE                                                        263 non-null    float64
#  4   LONGITUDE                                                       263 non-null    float64
#  5   Integral DEPTH (m)                                              263 non-null    float64
#  6   Trichodesmium nifH Gene (x106 copies m-2)                       223 non-null    object
#  7   Trichodesmium Biomass Conversion factor (mg C/106 nifH copies)  103 non-null    float64
#  8   Trichodesmium Biomass (mg C m-2)                                103 non-null    float64
#  9   UCYN-A1 nifH Gene (x106 copies m-2)                             72 non-null     object
#  10  UCYN-A2 nifH Gene (x106 copies m-2)                             68 non-null     object
#  11  UCYN-A nifH Gene (x106 copies m-2)                              253 non-null    object
#  12  UCYN-A Biomass Conversion factor (mg C/106 nifH copies)         104 non-null    float64
#  13  UCYN-B nifH Gene (x106 copies m-2)                              226 non-null    object
#  14  UCYN-B Biomass Conversion factor (mg C/106 nifH copies)         103 non-null    float64
#  15  UCYN-C nifH Gene (x106 copies m-2)                              98 non-null     object
#  16  UCYN-C Biomass Conversion factor (mg C/106 nifH copies)         30 non-null     float64
#  17  UCYN Biomass (mg C m-2)                                         109 non-null    float64
#  18  Richelia Associated Species                                     62 non-null     object
#  19  Richelia nifH Gene (x106 copies m-2)                            144 non-null    object
#  20  Richelia Biomass Conversion factor (mg C/106 nifH copies)       63 non-null     float64
#  21  Calothrix Associated Species                                    11 non-null     object
#  22  Calothrix nifH Gene  (x106 copies m-2)                          11 non-null     float64
#  23  Calothrix Biomass Conversion factor (mg C/106 nifH copies)      12 non-null     float64
#  24  Heterocyst (Richelia & Calotrhix) Biomass (mg C m-2)            63 non-null     float64
#  25  Gamma 1 nifH Gene (x106 copies/m3)                              0 non-null      float64
#  26  Gamma 2 nifH Gene (x106 copies/m3)                              0 non-null      float64
#  27  Gamma 3 nifH Gene (x106 copies/m3)                              0 non-null      float64
#  28  Gamma 4 nifH Gene (x106 copies/m3)                              0 non-null      float64
#  29  Gamma nifH Gene (x106 copies/m3)                                70 non-null     object
#  30  alpha nifH Gene (x106 copies/m3)                                0 non-null      float64
#  31  Beta nifH Gene (x106 copies/m3)                                 0 non-null      float64
#  32  CIII nifH Gene (x106 copies/m3)                                 0 non-null      float64
#  33  Total Diazotrophic Biomass (mg C m-2)                           0 non-null      float64
#  34  Surface Temperature (˚C)                                        134 non-null    float64
#  35  Surface Salinity (PSU)                                          115 non-null    float64
#  36  Surface Nitrate (µM)                                            135 non-null    object
#  37  Surface Phosphate (µM)                                          135 non-null    object
#  38  N:P ratio                                                       45 non-null     float64
#  39  Surface Fe (nM)                                                 1 non-null      float64
#  40  Chlorophyll  (mg m-2)                                           66 non-null     float64
#  41  Notes                                                           11 non-null     object
# dtypes: float64(26), object(16)
# memory usage: 86.4+ KB
# None
#                                         SOURCE: Data  \
# 0  Takuhei Shiozaki et al., 2014. Continetal Shel...
# 1                                                NaN
# 2                              data shown in table 3
# 3                                                NaN
# 4                                                NaN
#
#   METHODS:                  Sampling/Analysis DATE (yyyy-mm-dd)  LATITUDE  \
# 0                                        qPCR         2010 May       21.5
# 1                                        qPCR         2010 May       21.5
# 2                                        qPCR         2010 May       21.0
# 3                                        qPCR         2010 May       21.0
# 4                                        qPCR         2010 May       21.0
#
#    LONGITUDE  Integral DEPTH (m) Trichodesmium nifH Gene (x106 copies m-2)  \
# 0      122.0               200.0                                  12000.00
# 1      122.5               200.0                                  16000.00
# 2      120.0               200.0                                   2100.00
# 3      119.5               200.0                                   1500.00
# 4      118.0               200.0                                  12000.00
#
#    Trichodesmium Biomass Conversion factor (mg C/106 nifH copies)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Trichodesmium Biomass (mg C m-2) UCYN-A1 nifH Gene (x106 copies m-2)  ...  \
# 0                               NaN                                 NaN  ...
# 1                               NaN                                 NaN  ...
# 2                               NaN                                 NaN  ...
# 3                               NaN                                 NaN  ...
# 4                               NaN                                 NaN  ...
#
#   CIII nifH Gene (x106 copies/m3) Total Diazotrophic Biomass (mg C m-2)  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
#
#    Surface Temperature (˚C) Surface Salinity (PSU)  Surface Nitrate (µM)  \
# 0                       NaN                    NaN                  0.02
# 1                       NaN                    NaN                  0.01
# 2                       NaN                    NaN                  0.01
# 3                       NaN                    NaN                  0.02
# 4                       NaN                    NaN                  0.01
#
#   Surface Phosphate (µM)  N:P ratio  Surface Fe (nM) Chlorophyll  (mg m-2)  \
# 0                   0.03        NaN              NaN                   NaN
# 1                   0.08        NaN              NaN                   NaN
# 2                   0.03        NaN              NaN                   NaN
# 3                   0.03        NaN              NaN                   NaN
# 4                   0.04        NaN              NaN                   NaN
#
#   Notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 42 columns]

# %%
tang_cols = ['Trichodesmium nifH Gene (x106 copies m-2)','UCYN-A nifH Gene (x106 copies m-2)','UCYN-B nifH Gene (x106 copies m-2)']

#first step
objToNum(tang_nifh)
tang_nifh.fillna(0, inplace=True)

#second step
tang_nifh_df = tang_nifh
#tang_nifh_df = removeEmptyRows(tang_cols,tang_nifh_df)

#check that nothign is lost
print(len(tang_nifh_df))
# Out:
# 263

# %%
from parula_diy import parula_map

plotColsOnMap(
    tang_cols,tang_nifh_df,
    constant=(10**6), 
    transf=(lambda x: np.log10(x+10)),
    min_lim=6,
    max_lim=11,
    cmap=parula_map,
    colorbar_label="nifH Gene (copies m-3)",
    title="Tang depth integrated data presented in the exel file",
    s=30
    )
